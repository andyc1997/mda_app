# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import missingno

from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder
from sklearn.svm import SVR

# %cd C:\Users\user\Desktop\KUL - Mstat\Modern Data Analytics\proj\
# Out:
# C:\Users\user\Desktop\KUL - Mstat\Modern Data Analytics\proj

# %%
# import data
mortality = pd.read_csv('mortality_merged.csv')

# %%
# Check for missing values, it seems alright
missingno.matrix(mortality)

# %%
# Summer period, comment it out if you want to do for the whole period
def get_summer(df):
    return df[(df['MONTH'] <= 8) & (df['MONTH'] >= 5)]
mortality = get_summer(mortality)

# %%
# Train-test split
TEST_SIZE = 0.1
SEED = 467051528
X_train, X_test, y_train, y_test = train_test_split(mortality.drop('COUNT', axis = 1), 
                                                    mortality['COUNT'], 
                                                    test_size = TEST_SIZE,
                                                    random_state = SEED,
                                                    shuffle = True)

# %%
# Preprocessing steps
numeric_transformer = Pipeline(steps = [
    ('scaler', StandardScaler())
])
categorical_transformer = OneHotEncoder(drop = 'first')

categorical_features = ['REGION', 'AGE-GROUP', 'SEX', 'COD']
numeric_features = X_train.columns.to_list()[6:]

preprocessor = ColumnTransformer(
    transformers = [
        ('drop_columns', 'drop', ['YEAR', 'MONTH']),
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
# Parameter grids
deg = np.arange(3, 8)
gamma = np.arange(0.005, 0.10, 0.005)
C = np.arange(0.0, 4.0, 0.1)
epsilon = np.arange(0.01, 0.5, 0.05)
params = {'preprocessing__num' : [StandardScaler(), RobustScaler()], 
         'regressor__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
         'regressor__degree': deg, 
         'regressor__gamma': gamma,
         'regressor__C': C,
         'regressor__epsilon': epsilon}

# %%
# Model
model = Pipeline(steps = [
    ('preprocessing', preprocessor),
    ('regressor', SVR())
])

# %%
# Grid search
search = RandomizedSearchCV(model, 
                            param_distributions = params, 
                            random_state = SEED)
search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('drop_columns',
#                                                                                'drop',
#                                                                                ['YEAR',
#                                                                                 'MONTH']),
#                                                                               ('num',
#                                                                                Pipeline(steps=[('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['TEMP_MEAN',
#                                                                                 'TEMP_RNG',
#                                                                                 'WS50M_MEAN',
#                                                                                 'PRECTOT_MEAN',
#                                                                                 'RH2M_MEAN',
#                                                                                 'HEAT_DAYS']),
#                                                                               ('cat',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                ['REGION',
#                                                                                 'AGE-GROUP',
#                                                                                 'SEX',
#                                                                                 'COD'])])),
#                                              ('regresso...
#        2.6, 2.7, 2.8, 2.9, 3. , 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8,
#        3.9]),
#                                         'regressor__degree': array([3, 4, 5, 6, 7]),
#                                         'regressor__epsilon': array([0.01, 0.06, 0.11, 0.16, 0.21, 0.26, 0.31, 0.36, 0.41, 0.46]),
#                                         'regressor__gamma': array([0.005, 0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035, 0.04 , 0.045,
#        0.05 , 0.055, 0.06 , 0.065, 0.07 , 0.075, 0.08 , 0.085, 0.09 ,
#        0.095]),
#                                         'regressor__kernel': ['linear', 'poly',
#                                                               'rbf',
#                                                               'sigmoid']},
#                    random_state=467051528)

# %%
# Summary of grid search
pd.DataFrame(search.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       5.039579      0.030956         0.817641        0.003722
# 1       3.814891      0.022047         0.730531        0.007275
# 2       3.930094      0.020326         0.699074        0.004356
# 3       3.604998      0.030614         0.634581        0.003924
# 4       3.985270      0.023758         0.763300        0.007314
# 5       3.969566      0.017834         0.741729        0.003781
# 6       4.015042      0.064487         0.721409        0.005706
# 7       4.273148      0.250020         0.737845        0.013452
# 8       4.108478      0.398998         0.693833        0.030813
# 9       3.842331      0.043799         0.608309        0.006841
#
#   param_regressor__kernel param_regressor__gamma param_regressor__epsilon  \
# 0                 sigmoid                   0.09                     0.11
# 1                 sigmoid                   0.01                     0.46
# 2                     rbf                  0.065                     0.26
# 3                     rbf                   0.03                     0.41
# 4                 sigmoid                   0.03                     0.21
# 5                    poly                  0.055                     0.46
# 6                     rbf                  0.045                     0.11
# 7                     rbf                  0.015                     0.01
# 8                     rbf                  0.085                     0.06
# 9                  linear                  0.025                     0.11
#
#   param_regressor__degree param_regressor__C param_preprocessing__num  \
# 0                       4                2.8           RobustScaler()
# 1                       5                2.9         StandardScaler()
# 2                       3                3.6           RobustScaler()
# 3                       4                2.3         StandardScaler()
# 4                       3                0.4         StandardScaler()
# 5                       6                1.9           RobustScaler()
# 6                       5                  2           RobustScaler()
# 7                       7                2.3           RobustScaler()
# 8                       7                  3         StandardScaler()
# 9                       4                  2         StandardScaler()
#
#                                               params  split0_test_score  \
# 0  {'regressor__kernel': 'sigmoid', 'regressor__g...          -0.395073
# 1  {'regressor__kernel': 'sigmoid', 'regressor__g...           0.088333
# 2  {'regressor__kernel': 'rbf', 'regressor__gamma...           0.316260
# 3  {'regressor__kernel': 'rbf', 'regressor__gamma...           0.189565
# 4  {'regressor__kernel': 'sigmoid', 'regressor__g...           0.012206
# 5  {'regressor__kernel': 'poly', 'regressor__gamm...          -0.127525
# 6  {'regressor__kernel': 'rbf', 'regressor__gamma...           0.224594
# 7  {'regressor__kernel': 'rbf', 'regressor__gamma...           0.153406
# 8  {'regressor__kernel': 'rbf', 'regressor__gamma...           0.270258
# 9  {'regressor__kernel': 'linear', 'regressor__ga...           0.273780
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.364979          -0.447879          -0.446059          -0.393776
# 1           0.072757           0.100204           0.077393           0.081542
# 2           0.284339           0.328814           0.290618           0.302284
# 3           0.165325           0.201096           0.174165           0.179747
# 4           0.002526           0.021929           0.009413           0.010474
# 5          -0.120501          -0.120294          -0.114089          -0.116389
# 6           0.198220           0.235790           0.205514           0.213870
# 7           0.134147           0.166038           0.139890           0.146524
# 8           0.241991           0.283037           0.254029           0.261065
# 9           0.242246           0.286644           0.243381           0.260752
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.409553        0.032394               10
# 1         0.084046        0.009565                7
# 2         0.304463        0.016331                1
# 3         0.181980        0.012381                5
# 4         0.011310        0.006245                8
# 5        -0.119760        0.004575                9
# 6         0.215598        0.013381                4
# 7         0.148001        0.011086                6
# 8         0.262076        0.013968                2
# 9         0.261361        0.017219                3

# %%
# Best fitted scores
print(search.best_params_)
print('Best scores: ', search.best_score_)
# Out:
# {'regressor__kernel': 'rbf', 'regressor__gamma': 0.065, 'regressor__epsilon': 0.26, 'regressor__degree': 3, 'regressor__C': 3.6, 'preprocessing__num': RobustScaler()}
# Best scores:  0.3044631266249551

# %%
# Test performance
model_chosen = search.best_estimator_
y_pred = model_chosen.predict(X_test)

# %%
# Test loss
mean_squared_error(y_pred, y_test)
# Out:
# 1491.3351028743643

# %%
# Training loss
mean_squared_error(y_train, model_chosen.predict(X_train))
# Out:
# 1309.3155462845768

# %%
# Test data: y_test, y_pred
sns.regplot(y_test, y_pred, color = 'red')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# R-squared between y_pred and y_test
np.corrcoef(y_test, y_pred)
# Out:
# array([[1.        , 0.76263749],
#        [0.76263749, 1.        ]])

# %%
# Training data: y_test, y_pred_train
y_pred_train = model_chosen.predict(X_train)
sns.regplot(x = y_train, y = y_pred_train, color = 'blue')

# %%
# R-squared between y_pred and y_pred_train
np.corrcoef(y_train, y_pred_train)
# Out:
# array([[1.        , 0.75847915],
#        [0.75847915, 1.        ]])
